# %%
# !pip install pycaret
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.7/484.7 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 57.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 73.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 19.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 67.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.3 MB/s eta 0:00:00
# ...

# %%
data = get_data('pokemon')
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
data.to_csv("Pokemon.csv")

# %%
clustering_setup = setup(data)
# Out:
# <style type="text/css">
# #T_c1a7d_row6_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c1a7d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1a7d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c1a7d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1a7d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1a7d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c1a7d_row0_col1" class="data row0 col1" >8010</td>
#     </tr>
#     <tr>
#       <th id="T_c1a7d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c1a7d_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_c1a7d_row1_col1" class="data row1 col1" >(800, 13)</td>
#     </tr>
#     <tr>
# ...

# %%
from pycaret.clustering import *
kMeanClusteringParameters = setup(data)
# Out:
# <style type="text/css">
# #T_f9048_row6_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f9048" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9048_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f9048_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9048_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9048_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f9048_row0_col1" class="data row0 col1" >5493</td>
#     </tr>
#     <tr>
#       <th id="T_f9048_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9048_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_f9048_row1_col1" class="data row1 col1" >(800, 13)</td>
#     </tr>
#     <tr>
# ...

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_309fd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_309fd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_309fd_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_309fd_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_309fd_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_309fd_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_309fd_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_309fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_309fd_row0_col0" class="data row0 col0" >0.3346</td>
#       <td id="T_309fd_row0_col1" class="data row0 col1" >644.6890</td>
# ...

# %%
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
from pycaret.clustering import *

kMeanClusteringParameters = setup(data, verbose=False)
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_ce533" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce533_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ce533_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ce533_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ce533_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ce533_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ce533_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce533_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce533_row0_col0" class="data row0 col0" >0.3345</td>
#       <td id="T_ce533_row0_col1" class="data row0 col1" >644.6835</td>
# ...

# %%
birchClusteringParameters = setup(data, verbose=False)
birchClusteringModel = create_model('birch')
birchPrediction = assign_model(birchClusteringModel)
print("Birch Clustering:")
print(birchPrediction)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e2349" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2349_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e2349_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e2349_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e2349_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e2349_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e2349_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2349_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2349_row0_col0" class="data row0 col0" >0.3051</td>
#       <td id="T_e2349_row0_col1" class="data row0 col1" >593.0329</td>
# ...

# %%
hierarchicalClusteringParameters = setup(data, verbose=False)
hierarchicalClusteringModel = create_model('hclust', linkage='ward', affinity='euclidean')
hierarchicalPrediction = assign_model(hierarchicalClusteringModel)
print("Hierarchical Clustering:")
print(hierarchicalPrediction)
# Out:
# <style type="text/css">
# </style>
# <table id="T_25ba7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25ba7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_25ba7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_25ba7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_25ba7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_25ba7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_25ba7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25ba7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25ba7_row0_col0" class="data row0 col0" >0.3051</td>
#       <td id="T_25ba7_row0_col1" class="data row0 col1" >593.0329</td>
# ...

# %%
X = save_model(KMeanClusteringModel, 'kMeanClusteringModelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
y=save_model(hierarchicalClusteringModel, 'hierarchicalClusteringModelfile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
z=save_model(birchClusteringModel, 'birchClusteringModelfile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_81c77" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81c77_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_81c77_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_81c77_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_81c77_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_81c77_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_81c77_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81c77_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81c77_row0_col0" class="data row0 col0" >0.3229</td>
#       <td id="T_81c77_row0_col1" class="data row0 col1" >651.9984</td>
# ...

# %%
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_e3a5a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3a5a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e3a5a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e3a5a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e3a5a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e3a5a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e3a5a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3a5a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3a5a_row0_col0" class="data row0 col0" >0.3074</td>
#       <td id="T_e3a5a_row0_col1" class="data row0 col1" >617.5637</td>
# ...

# %%
print("For Cluster = 3")
x = create_model('birch', num_clusters = 3)

print("For Cluster = 4")
x = create_model('birch', num_clusters = 4)

print("For Cluster = 5")
x = create_model('birch', num_clusters = 5)

print("For Cluster = 6")
x = create_model('birch', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_ffe45" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffe45_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ffe45_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ffe45_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ffe45_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ffe45_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ffe45_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffe45_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ffe45_row0_col0" class="data row0 col0" >0.3074</td>
#       <td id="T_ffe45_row0_col1" class="data row0 col1" >617.5637</td>
# ...

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Normalization

# %%
setup(data = data, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_839f0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_839f0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_839f0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_839f0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_839f0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_839f0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_839f0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_839f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_839f0_row0_col0" class="data row0 col0" >0.0027</td>
#       <td id="T_839f0_row0_col1" class="data row0 col1" >2.4812</td>
# ...

# %%
setup(data = data, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('birch')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1aa4c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1aa4c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1aa4c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1aa4c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1aa4c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1aa4c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1aa4c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1aa4c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1aa4c_row0_col0" class="data row0 col0" >0.0025</td>
#       <td id="T_1aa4c_row0_col1" class="data row0 col1" >2.2775</td>
# ...

# %%
setup(data = data, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_5c849" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c849_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5c849_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5c849_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5c849_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5c849_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5c849_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c849_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c849_row0_col0" class="data row0 col0" >0.0025</td>
#       <td id="T_5c849_row0_col1" class="data row0 col1" >2.2775</td>
# ...

# %%
print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_1c739" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c739_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1c739_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1c739_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1c739_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1c739_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1c739_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c739_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1c739_row0_col0" class="data row0 col0" >0.0029</td>
#       <td id="T_1c739_row0_col1" class="data row0 col1" >2.6857</td>
# ...

# %%
print("For Cluster = 3")
x = create_model('birch', num_clusters = 3)

print("For Cluster = 4")
x = create_model('birch', num_clusters = 4)

print("For Cluster = 5")
x = create_model('birch', num_clusters = 5)

print("For Cluster = 6")
x = create_model('birch', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_aea2c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aea2c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_aea2c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_aea2c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_aea2c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_aea2c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_aea2c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aea2c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aea2c_row0_col0" class="data row0 col0" >0.0026</td>
#       <td id="T_aea2c_row0_col1" class="data row0 col1" >2.3827</td>
# ...

# %%
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_a0f73" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0f73_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a0f73_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a0f73_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a0f73_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a0f73_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a0f73_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0f73_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0f73_row0_col0" class="data row0 col0" >0.0026</td>
#       <td id="T_a0f73_row0_col1" class="data row0 col1" >2.3827</td>
# ...

# %% [markdown]
# ### Transformation

# %%
setup(data = data, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_6b20e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b20e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6b20e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6b20e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6b20e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6b20e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6b20e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b20e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b20e_row0_col0" class="data row0 col0" >0.3493</td>
#       <td id="T_6b20e_row0_col1" class="data row0 col1" >1024.7136</td>
# ...

# %%
setup(data = data, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('birch')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_54ab3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54ab3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_54ab3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_54ab3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_54ab3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_54ab3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_54ab3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54ab3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54ab3_row0_col0" class="data row0 col0" >0.3217</td>
#       <td id="T_54ab3_row0_col1" class="data row0 col1" >898.5664</td>
# ...

# %%
setup(data = data, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_f2ae4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2ae4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f2ae4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f2ae4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f2ae4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f2ae4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f2ae4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2ae4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2ae4_row0_col0" class="data row0 col0" >0.2907</td>
#       <td id="T_f2ae4_row0_col1" class="data row0 col1" >866.5169</td>
# ...

# %%
setup(data = data, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_0b434" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b434_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0b434_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0b434_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0b434_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0b434_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0b434_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b434_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0b434_row0_col0" class="data row0 col0" >0.4008</td>
#       <td id="T_0b434_row0_col1" class="data row0 col1" >1167.6152</td>
# ...

# %%
setup(data = data, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
print("For Cluster = 3")
x = create_model('birch', num_clusters = 3)

print("For Cluster = 4")
x = create_model('birch', num_clusters = 4)

print("For Cluster = 5")
x = create_model('birch', num_clusters = 5)

print("For Cluster = 6")
x = create_model('birch', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_29645" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29645_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_29645_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_29645_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_29645_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_29645_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_29645_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29645_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29645_row0_col0" class="data row0 col0" >0.3690</td>
#       <td id="T_29645_row0_col1" class="data row0 col1" >1002.2264</td>
# ...

# %%
setup(data = data, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_7daa5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7daa5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7daa5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7daa5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7daa5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7daa5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7daa5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7daa5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7daa5_row0_col0" class="data row0 col0" >0.3360</td>
#       <td id="T_7daa5_row0_col1" class="data row0 col1" >907.6853</td>
# ...

# %% [markdown]
# ### PCA

# %%
setup(data = data, pca = True, pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_acdff" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_acdff_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_acdff_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_acdff_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_acdff_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_acdff_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_acdff_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acdff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_acdff_row0_col0" class="data row0 col0" >0.3345</td>
#       <td id="T_acdff_row0_col1" class="data row0 col1" >644.6835</td>
# ...

# %%
setup(data = data, pca = True, pca_method = 'linear', verbose=False)
x = create_model('birch')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_72b40" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72b40_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_72b40_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_72b40_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_72b40_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_72b40_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_72b40_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72b40_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72b40_row0_col0" class="data row0 col0" >0.3051</td>
#       <td id="T_72b40_row0_col1" class="data row0 col1" >593.0329</td>
# ...

# %%
setup(data = data, pca = True, pca_method = 'linear', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_152ea" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_152ea_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_152ea_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_152ea_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_152ea_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_152ea_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_152ea_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_152ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_152ea_row0_col0" class="data row0 col0" >0.3051</td>
#       <td id="T_152ea_row0_col1" class="data row0 col1" >593.0329</td>
# ...

# %%
setup(data = data, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_0b97a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b97a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0b97a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0b97a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0b97a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0b97a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0b97a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b97a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0b97a_row0_col0" class="data row0 col0" >0.3283</td>
#       <td id="T_0b97a_row0_col1" class="data row0 col1" >652.4995</td>
# ...

# %%
setup(data = data, pca = True, pca_method = 'linear', verbose=False)
print("For Cluster = 3")
x = create_model('birch', num_clusters = 3)

print("For Cluster = 4")
x = create_model('birch', num_clusters = 4)

print("For Cluster = 5")
x = create_model('birch', num_clusters = 5)

print("For Cluster = 6")
x = create_model('birch', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_22fd9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22fd9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_22fd9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_22fd9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_22fd9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_22fd9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_22fd9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22fd9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22fd9_row0_col0" class="data row0 col0" >0.3074</td>
#       <td id="T_22fd9_row0_col1" class="data row0 col1" >617.5637</td>
# ...

# %%
setup(data = data, pca = True, pca_method = 'linear', verbose=False)
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_aeab6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aeab6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_aeab6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_aeab6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_aeab6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_aeab6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_aeab6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aeab6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aeab6_row0_col0" class="data row0 col0" >0.3074</td>
#       <td id="T_aeab6_row0_col1" class="data row0 col1" >617.5637</td>
# ...

# %% [markdown]
# ### Transformaton" + "Normalization

# %%
setup(data = data, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c84d6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c84d6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c84d6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c84d6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c84d6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c84d6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c84d6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c84d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c84d6_row0_col0" class="data row0 col0" >0.0032</td>
#       <td id="T_c84d6_row0_col1" class="data row0 col1" >2.5002</td>
# ...

# %%
setup(data = data, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('birch')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1a02e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a02e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1a02e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1a02e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1a02e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1a02e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1a02e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a02e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a02e_row0_col0" class="data row0 col0" >0.0038</td>
#       <td id="T_1a02e_row0_col1" class="data row0 col1" >2.3036</td>
# ...

# %%
setup(data = data, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_f797b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f797b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f797b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f797b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f797b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f797b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f797b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f797b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f797b_row0_col0" class="data row0 col0" >0.0038</td>
#       <td id="T_f797b_row0_col1" class="data row0 col1" >2.3036</td>
# ...

# %%
setup(data = data, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_8dbd8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dbd8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8dbd8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8dbd8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8dbd8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8dbd8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8dbd8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dbd8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8dbd8_row0_col0" class="data row0 col0" >0.0036</td>
#       <td id="T_8dbd8_row0_col1" class="data row0 col1" >2.8327</td>
# ...

# %%
setup(data = data, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
print("For Cluster = 3")
x = create_model('birch', num_clusters = 3)

print("For Cluster = 4")
x = create_model('birch', num_clusters = 4)

print("For Cluster = 5")
x = create_model('birch', num_clusters = 5)

print("For Cluster = 6")
x = create_model('birch', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_d40c0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d40c0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d40c0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d40c0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d40c0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d40c0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d40c0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d40c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d40c0_row0_col0" class="data row0 col0" >0.0058</td>
#       <td id="T_d40c0_row0_col1" class="data row0 col1" >2.4038</td>
# ...

# %%
setup(data = data, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_5cd4c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5cd4c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5cd4c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5cd4c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5cd4c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5cd4c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5cd4c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5cd4c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5cd4c_row0_col0" class="data row0 col0" >0.0058</td>
#       <td id="T_5cd4c_row0_col1" class="data row0 col1" >2.4038</td>
# ...

# %% [markdown]
# ### Transformation"+"Normalisation"+"PCA

# %%
setup(data = data, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_88e94" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88e94_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_88e94_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_88e94_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_88e94_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_88e94_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_88e94_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88e94_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88e94_row0_col0" class="data row0 col0" >0.0027</td>
#       <td id="T_88e94_row0_col1" class="data row0 col1" >2.4360</td>
# ...

# %%
setup(data = data, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
x = create_model('birch')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ab063" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab063_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ab063_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ab063_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ab063_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ab063_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ab063_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab063_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ab063_row0_col0" class="data row0 col0" >0.0038</td>
#       <td id="T_ab063_row0_col1" class="data row0 col1" >2.3036</td>
# ...

# %%
setup(data = data, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_5e441" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e441_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5e441_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5e441_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5e441_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5e441_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5e441_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e441_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e441_row0_col0" class="data row0 col0" >0.0038</td>
#       <td id="T_5e441_row0_col1" class="data row0 col1" >2.3036</td>
# ...

# %%
setup(data = data, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_a6044" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6044_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a6044_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a6044_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a6044_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a6044_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a6044_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6044_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6044_row0_col0" class="data row0 col0" >0.0017</td>
#       <td id="T_a6044_row0_col1" class="data row0 col1" >2.6100</td>
# ...

# %%
setup(data = data, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
print("For Cluster = 3")
x = create_model('birch', num_clusters = 3)

print("For Cluster = 4")
x = create_model('birch', num_clusters = 4)

print("For Cluster = 5")
x = create_model('birch', num_clusters = 5)

print("For Cluster = 6")
x = create_model('birch', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_a2a81" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2a81_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a2a81_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a2a81_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a2a81_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a2a81_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a2a81_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2a81_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2a81_row0_col0" class="data row0 col0" >0.0058</td>
#       <td id="T_a2a81_row0_col1" class="data row0 col1" >2.4038</td>
# ...

# %%
setup(data = data, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_bdafe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdafe_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bdafe_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bdafe_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bdafe_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bdafe_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bdafe_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdafe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bdafe_row0_col0" class="data row0 col0" >0.0058</td>
#       <td id="T_bdafe_row0_col1" class="data row0 col1" >2.4038</td>
# ...

# %%
import pandas as pd

# Sample results
kmeans_results = {
    'No Preprocessing': {
        3: {'Silhouette':0.3229, 'Calinski-Harabasz': 651.9984, 'Davies-Bouldin': 1.1127},
        4: {'Silhouette': 0.3345	, 'Calinski-Harabasz': 644.6835, 'Davies-Bouldin': 0.9707},
        5: {'Silhouette': 0.3195, 'Calinski-Harabasz': 629.0829, 'Davies-Bouldin':1.0147	},
        6: {'Silhouette': 0.3270, 'Calinski-Harabasz': 651.4176, 'Davies-Bouldin': 0.9497}
    },
    'Normalization': {
        3: {'Silhouette': 0.0029, 'Calinski-Harabasz': 2.6857, 'Davies-Bouldin': 12.9357},
        4: {'Silhouette': 0.0027, 'Calinski-Harabasz': 2.4812, 'Davies-Bouldin': 10.6348	},
        5: {'Silhouette': 0.0023, 'Calinski-Harabasz': 2.2750, 'Davies-Bouldin': 10.6479},
        6: {'Silhouette':0.0023	, 'Calinski-Harabasz': 2.1470, 'Davies-Bouldin': 10.1138	}
    },
    'Transformation': {
        3: {'Silhouette': 0.4008, 'Calinski-Harabasz': 1167.6152, 'Davies-Bouldin': 0.8744},
        4: {'Silhouette':0.3459	, 'Calinski-Harabasz': 1024.8411, 'Davies-Bouldin': 1.0108},
        5: {'Silhouette': 0.3538, 'Calinski-Harabasz': 974.3792, 'Davies-Bouldin': 0.9322},
        6: {'Silhouette':0.3506, 'Calinski-Harabasz': 964.7733, 'Davies-Bouldin': 0.9312}
    },
    'PCA': {
        3: {'Silhouette': 0.3283	, 'Calinski-Harabasz': 652.4995, 'Davies-Bouldin': 1.0804},
        4: {'Silhouette': 0.3346, 'Calinski-Harabasz': 644.6890, 'Davies-Bouldin':0.9713},
        5: {'Silhouette': 0.3202	, 'Calinski-Harabasz': 629.4024, 'Davies-Bouldin': 1.0133	},
        6: {'Silhouette': 0.3270, 'Calinski-Harabasz': 651.4176	, 'Davies-Bouldin': 0.9497}
    },
    'Transformation + Normalization': {
        3: {'Silhouette': 0.0036, 'Calinski-Harabasz': 2.8327, 'Davies-Bouldin':11.4686},
        4: {'Silhouette': 0.0025	, 'Calinski-Harabasz': 2.4888, 'Davies-Bouldin': 11.4152},
        5: {'Silhouette': 0.0000, 'Calinski-Harabasz':2.2530	, 'Davies-Bouldin': 11.1939},
        6: {'Silhouette': 0.0032, 'Calinski-Harabasz': 2.2259, 'Davies-Bouldin': 9.8378}
    },
    'Transformation + Normalization + PCA': {
        3: {'Silhouette': 0.0017, 'Calinski-Harabasz':2.6100	, 'Davies-Bouldin': 11.0089},
        4: {'Silhouette': 0.0021, 'Calinski-Harabasz': 2.4726	, 'Davies-Bouldin': 11.2756},
        5: {'Silhouette': 0.0024, 'Calinski-Harabasz': 2.2341, 'Davies-Bouldin': 11.9680},
        6: {'Silhouette': 0.0028, 'Calinski-Harabasz': 2.1725, 'Davies-Bouldin': 10.1205}
    },
}

# Create a DataFrame for each algorithm
kmeans_df = pd.DataFrame()

for preprocessing, values in kmeans_results.items():
    preprocessing_df = pd.DataFrame(values).T
    preprocessing_df.insert(0, 'Preprocessing', preprocessing)
    kmeans_df = pd.concat([kmeans_df, preprocessing_df], axis=0)

# # Display the final DataFrame for kmeans
# print("Results for kmeans model:")
# print(kmeans_df)

# Save to CSV
kmeans_df.to_csv('kmeans_result.csv', index=True)

# %%
import pandas as pd
from tabulate import tabulate

# Read the CSV file
df = pd.read_csv('kmeans_result.csv')

# Display the DataFrame using tabulate for a more beautiful format
print(tabulate(df, headers='keys', tablefmt='pretty'))
# Out:
# +----+------------+--------------------------------------+------------+-------------------+----------------+
# |    | Unnamed: 0 |            Preprocessing             | Silhouette | Calinski-Harabasz | Davies-Bouldin |
# +----+------------+--------------------------------------+------------+-------------------+----------------+
# | 0  |     3      |           No Preprocessing           |   0.3229   |     651.9984      |     1.1127     |
# | 1  |     4      |           No Preprocessing           |   0.3345   |     644.6835      |     0.9707     |
# | 2  |     5      |           No Preprocessing           |   0.3195   |     629.0829      |     1.0147     |
# | 3  |     6      |           No Preprocessing           |   0.327    |     651.4176      |     0.9497     |
# | 4  |     3      |            Normalization             |   0.0029   |      2.6857       |    12.9357     |
# | 5  |     4      |            Normalization             |   0.0027   |      2.4812       |    10.6348     |
# ...

# %%
import pandas as pd

# Sample results for hierarchical clustering
hierarchical_results = {
    'No Preprocessing': {
        3: {'Silhouette': 0.3074, 'Calinski-Harabasz': 617.5637, 'Davies-Bouldin': 1.1099},
        4: {'Silhouette': 0.3051, 'Calinski-Harabasz': 593.0329, 'Davies-Bouldin': 1.0624},
        5: {'Silhouette': 0.2858, 'Calinski-Harabasz': 560.0705, 'Davies-Bouldin': 0.9716},
        6: {'Silhouette': 0.2897, 'Calinski-Harabasz': 578.8342, 'Davies-Bouldin': 0.9853}
    },
    'Normalization': {
        3: {'Silhouette':0.0026, 'Calinski-Harabasz': 2.3827, 'Davies-Bouldin': 14.7393},
        4: {'Silhouette': 0.0025, 'Calinski-Harabasz':2.2775, 'Davies-Bouldin': 12.4826},
        5: {'Silhouette': 0.0007, 'Calinski-Harabasz': 2.2261, 'Davies-Bouldin': 11.3553},
        6: {'Silhouette': 0.0013, 'Calinski-Harabasz': 2.1962, 'Davies-Bouldin': 10.3608}
    },
    'Transformation': {
        3: {'Silhouette':0.3360, 'Calinski-Harabasz': 907.6853, 'Davies-Bouldin': 0.9623},
        4: {'Silhouette': 0.2907, 'Calinski-Harabasz': 866.5169, 'Davies-Bouldin': 1.0782},
        5: {'Silhouette': 0.2842, 'Calinski-Harabasz': 819.6468, 'Davies-Bouldin': 1.0426},
        6: {'Silhouette': 0.2936, 'Calinski-Harabasz': 822.2987, 'Davies-Bouldin': 0.9730}
    },
    'PCA': {
        3: {'Silhouette': 0.3074, 'Calinski-Harabasz': 617.5637, 'Davies-Bouldin': 1.1099},
        4: {'Silhouette':0.3051, 'Calinski-Harabasz': 593.0329, 'Davies-Bouldin': 1.0624},
        5: {'Silhouette':0.2858, 'Calinski-Harabasz': 560.0705, 'Davies-Bouldin': 0.9716},
        6: {'Silhouette':0.2897, 'Calinski-Harabasz':578.8342, 'Davies-Bouldin': 0.9853}
    },
    'Transformation + Normalization': {
        3: {'Silhouette':0.0058, 'Calinski-Harabasz': 2.4038, 'Davies-Bouldin': 13.9126},
        4: {'Silhouette': 0.0038, 'Calinski-Harabasz': 2.3036, 'Davies-Bouldin': 11.7875},
        5: {'Silhouette': 0.0018, 'Calinski-Harabasz': 2.2544, 'Davies-Bouldin': 10.7864},
        6: {'Silhouette': 0.0024, 'Calinski-Harabasz': 2.2129, 'Davies-Bouldin': 9.8862}
    },
    'Transformation + Normalization + PCA': {
       3: {'Silhouette':0.0058, 'Calinski-Harabasz': 2.4038, 'Davies-Bouldin': 13.9126},
        4: {'Silhouette': 0.0038, 'Calinski-Harabasz': 2.3036, 'Davies-Bouldin': 11.7875},
        5: {'Silhouette': 0.0018, 'Calinski-Harabasz': 2.2544, 'Davies-Bouldin': 10.7864},
        6: {'Silhouette': 0.0024, 'Calinski-Harabasz': 2.2129, 'Davies-Bouldin': 9.8862}
    },
}

# Create a DataFrame for each algorithm
hierarchical_df = pd.DataFrame()

for preprocessing, values in hierarchical_results.items():
    preprocessing_df = pd.DataFrame(values).T
    preprocessing_df.insert(0, 'Preprocessing', preprocessing)
#     preprocessing_df['Cluster'] = preprocessing_df.index.astype(int)
    hierarchical_df = pd.concat([hierarchical_df, preprocessing_df], axis=0)

# # Reset the index
# hierarchical_df = hierarchical_df.reset_index(drop=True)

# # Reorder the columns
# hierarchical_df = hierarchical_df[['Cluster', 'Preprocessing', 3, 4, 5, 6]]

# Display the final DataFrame for hierarchical clustering
print("Results for hierarchical clustering:")
print(hierarchical_df)

# Save to CSV
hierarchical_df.to_csv('hierarchical_resultss.csv', index=True)
# Out:
# Results for hierarchical clustering:
#                           Preprocessing  Silhouette  Calinski-Harabasz  \
# 3                      No Preprocessing      0.3074           617.5637
# 4                      No Preprocessing      0.3051           593.0329
# 5                      No Preprocessing      0.2858           560.0705
# 6                      No Preprocessing      0.2897           578.8342
# 3                         Normalization      0.0026             2.3827
# 4                         Normalization      0.0025             2.2775
# 5                         Normalization      0.0007             2.2261
# 6                         Normalization      0.0013             2.1962
# 3                        Transformation      0.3360           907.6853
# 4                        Transformation      0.2907           866.5169
# 5                        Transformation      0.2842           819.6468
# 6                        Transformation      0.2936           822.2987
# ...

# %%
# Read the CSV file
dff = pd.read_csv('hierarchical_resultss.csv')

# Display the DataFrame using tabulate for a more beautiful format
print(tabulate(dff, headers='keys', tablefmt='pretty'))
# Out:
# +----+------------+--------------------------------------+------------+-------------------+----------------+
# |    | Unnamed: 0 |            Preprocessing             | Silhouette | Calinski-Harabasz | Davies-Bouldin |
# +----+------------+--------------------------------------+------------+-------------------+----------------+
# | 0  |     3      |           No Preprocessing           |   0.3074   |     617.5637      |     1.1099     |
# | 1  |     4      |           No Preprocessing           |   0.3051   |     593.0329      |     1.0624     |
# | 2  |     5      |           No Preprocessing           |   0.2858   |     560.0705      |     0.9716     |
# | 3  |     6      |           No Preprocessing           |   0.2897   |     578.8342      |     0.9853     |
# | 4  |     3      |            Normalization             |   0.0026   |      2.3827       |    14.7393     |
# | 5  |     4      |            Normalization             |   0.0025   |      2.2775       |    12.4826     |
# ...

# %%
import pandas as pd

# Sample results for Birch clustering
birch_results = {
    'No Preprocessing': {
        3: {'Silhouette': 0.3074, 'Calinski-Harabasz': 617.5637, 'Davies-Bouldin': 1.1099},
        4: {'Silhouette': 0.3051, 'Calinski-Harabasz': 593.0329, 'Davies-Bouldin': 1.0624},
        5: {'Silhouette': 0.2858, 'Calinski-Harabasz': 560.07051, 'Davies-Bouldin':0.9716},
        6: {'Silhouette': 0.2897, 'Calinski-Harabasz': 578.8342	, 'Davies-Bouldin': 0.9853}
    },
    'Normalization': {
        3: {'Silhouette': 0.0026, 'Calinski-Harabasz': 2.3827, 'Davies-Bouldin': 14.7393},
        4: {'Silhouette': 0.0025, 'Calinski-Harabasz': 2.2775, 'Davies-Bouldin': 12.4826},
        5: {'Silhouette': 0.0007, 'Calinski-Harabasz': 2.2261, 'Davies-Bouldin': 11.3553},
        6: {'Silhouette': 0.0013, 'Calinski-Harabasz': 2.1962, 'Davies-Bouldin': 10.3608}
    },
    'Transformation': {
        3: {'Silhouette': 0.3690, 'Calinski-Harabasz': 1002.2264, 'Davies-Bouldin': 0.9212},
        4: {'Silhouette':0.3217, 'Calinski-Harabasz': 898.5664, 'Davies-Bouldin': 0.9545},
        5: {'Silhouette': 0.3156, 'Calinski-Harabasz': 917.7812, 'Davies-Bouldin': 0.9826},
        6: {'Silhouette': 0.3147, 'Calinski-Harabasz': 891.9438, 'Davies-Bouldin': 0.9926}
    },
    'PCA': {
        3: {'Silhouette': 0.3074, 'Calinski-Harabasz': 617.5637, 'Davies-Bouldin': 1.1099},
        4: {'Silhouette': 0.3051, 'Calinski-Harabasz': 593.0329, 'Davies-Bouldin': 1.0624},
        5: {'Silhouette': 0.2858, 'Calinski-Harabasz': 560.0705, 'Davies-Bouldin': 0.9716},
        6: {'Silhouette': 0.2897, 'Calinski-Harabasz': 578.8342, 'Davies-Bouldin': 0.9853}
    },
    'Transformation + Normalization': {
         3: {'Silhouette':0.0058, 'Calinski-Harabasz': 2.4038, 'Davies-Bouldin': 13.9126},
        4: {'Silhouette': 0.0038, 'Calinski-Harabasz': 2.3036, 'Davies-Bouldin': 11.7875},
        5: {'Silhouette': 0.0018, 'Calinski-Harabasz': 2.2544, 'Davies-Bouldin': 10.7864},
        6: {'Silhouette': 0.0024, 'Calinski-Harabasz': 2.2129, 'Davies-Bouldin': 9.8862}
    },
    'Transformation + Normalization + PCA': {
        3: {'Silhouette':0.0058, 'Calinski-Harabasz': 2.4038, 'Davies-Bouldin': 13.9126},
        4: {'Silhouette': 0.0038, 'Calinski-Harabasz': 2.3036, 'Davies-Bouldin': 11.7875},
        5: {'Silhouette': 0.0018, 'Calinski-Harabasz': 2.2544, 'Davies-Bouldin': 10.7864},
        6: {'Silhouette': 0.0024, 'Calinski-Harabasz': 2.2129, 'Davies-Bouldin': 9.8862}
    },
}

# Create a DataFrame for each algorithm
birch_df = pd.DataFrame()

for preprocessing, values in birch_results.items():
    preprocessing_df = pd.DataFrame(values).T
    preprocessing_df.insert(0, 'Preprocessing', preprocessing)
    birch_df = pd.concat([birch_df, preprocessing_df], axis=0)



# Display the final DataFrame for Birch clustering
print("Results for Birch clustering:")
print(birch_df)

# Save to CSV
birch_df.to_csv('birch_resultss.csv', index=True)
# Out:
# Results for Birch clustering:
#                           Preprocessing  Silhouette  Calinski-Harabasz  \
# 3                      No Preprocessing      0.3074          617.56370
# 4                      No Preprocessing      0.3051          593.03290
# 5                      No Preprocessing      0.2858          560.07051
# 6                      No Preprocessing      0.2897          578.83420
# 3                         Normalization      0.0026            2.38270
# 4                         Normalization      0.0025            2.27750
# 5                         Normalization      0.0007            2.22610
# 6                         Normalization      0.0013            2.19620
# 3                        Transformation      0.3690         1002.22640
# 4                        Transformation      0.3217          898.56640
# 5                        Transformation      0.3156          917.78120
# 6                        Transformation      0.3147          891.94380
# ...

# %%
# Read the CSV file
dfff = pd.read_csv('birch_resultss.csv')

# Display the DataFrame using tabulate for a more beautiful format
print(tabulate(dfff, headers='keys', tablefmt='pretty'))
# Out:
# +----+------------+--------------------------------------+------------+-------------------+----------------+
# |    | Unnamed: 0 |            Preprocessing             | Silhouette | Calinski-Harabasz | Davies-Bouldin |
# +----+------------+--------------------------------------+------------+-------------------+----------------+
# | 0  |     3      |           No Preprocessing           |   0.3074   |     617.5637      |     1.1099     |
# | 1  |     4      |           No Preprocessing           |   0.3051   |     593.0329      |     1.0624     |
# | 2  |     5      |           No Preprocessing           |   0.2858   |     560.07051     |     0.9716     |
# | 3  |     6      |           No Preprocessing           |   0.2897   |     578.8342      |     0.9853     |
# | 4  |     3      |            Normalization             |   0.0026   |      2.3827       |    14.7393     |
# | 5  |     4      |            Normalization             |   0.0025   |      2.2775       |    12.4826     |
# ...
